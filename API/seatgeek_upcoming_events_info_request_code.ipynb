# %%
import json
import http.client
import urllib.parse

# %%
# set paths for reaching API
seatgeek_api = "api.seatgeek.com"
api_path = "/2/events/"

# function to get the upcoming event info given the performer name
def get_upcoming_events(performer):

    # seatgeek requires the performer name to be in a 'slug' format
    # change the performer's name to replace the spaces with dashes & lowercase
    performer_slug = performer.replace(" ", "-").lower()

    # set API query parameters
    query_params = {
        'client_id': client_id, # not uploaded to github for privacy reasons
        'performers.slug': performer_slug,
        'per_page': 1  # only get 1 upcoming event
    }

    # URL encode the parameters - params must be in the query link
    encoded_params = urllib.parse.urlencode(query_params)

    # connect to the seatgeek API first
    conn = http.client.HTTPSConnection(seatgeek_api)

    # set the header and make the request
    headers = { 'Accept': "application/json" }
    conn.request("GET", f"{api_path}?{encoded_params}", headers=headers)

    # get the response and read it in
    response = conn.getresponse()
    data = response.read()

    # make sure to close the connection
    conn.close()

    # response parsing
    try:
        data_json = json.loads(data.decode("utf-8"))
        # if events are found, return the first (most recent/upcoming) event
        if data_json.get('events'):
            event = data_json['events'][0]
            event_info = {
                'event_name': event['title'],
                'event_datetime': event['datetime_utc'],
                'venue_name': event['venue']['name'],
                'venue_city': event['venue']['city']
            }
            return event_info
        else:
            print("No upcoming events found for", performer)
            return None
    except json.JSONDecodeError as e:
        print("Error parsing response for", performer + ":", e)
        return None
    except Exception as e:
        print("An error occurred:", e)
        return None

# edit file with charmetric work and add in upcoming info from seatgeek
# load the JSON data from the .txt file downloaded from the github charmetric work
file_path = '/content/transformed_city_top10artist_data.txt'
with open(file_path, 'r') as file:
    cities_data = json.load(file)

# go through each city + it's top artists & add event info
for city in cities_data:
    for artist in city.get('top_artists', []):
        performer = artist['name']
        event_info = get_upcoming_events(performer)
        # if there are upcoming events, new dictionary entry is added to the file
        if event_info:
            artist['upcoming_event'] = event_info

# save the file with the new json data
with open(file_path, 'w') as file:
    json.dump(cities_data, file, indent=4)
# Out:
# Fetching events for Drake...
# No upcoming events found for Drake
# Fetching events for Kendrick Lamar...
# Fetching events for Kanye West...
# No upcoming events found for Kanye West
# Fetching events for Future...
# Fetching events for Tyler, The Creator...
# No upcoming events found for Tyler, The Creator
# Fetching events for Lil Wayne...
# Fetching events for Metro Boomin...
# Fetching events for 21 Savage...
# No upcoming events found for 21 Savage
# Fetching events for Playboi Carti...
# Fetching events for Chappell Roan...
# No upcoming events found for Chappell Roan
# Fetching events for Kendrick Lamar...
# Fetching events for SZA...
# Fetching events for Drake...
# No upcoming events found for Drake
# Fetching events for Tyler, The Creator...
# No upcoming events found for Tyler, The Creator
# Fetching events for Kanye West...
# No upcoming events found for Kanye West
# Fetching events for Travis Scott...
# Fetching events for Future...
# Fetching events for Lil Wayne...
# Fetching events for Metro Boomin...
# Fetching events for 21 Savage...
# No upcoming events found for 21 Savage
# Fetching events for Kendrick Lamar...
# Fetching events for Drake...
# No upcoming events found for Drake
# Fetching events for Kanye West...
# No upcoming events found for Kanye West
# Fetching events for Tyler, The Creator...
# No upcoming events found for Tyler, The Creator
# Fetching events for Post Malone...
# Fetching events for Future...
# Fetching events for Lil Wayne...
# Fetching events for 21 Savage...
# No upcoming events found for 21 Savage
# Fetching events for Morgan Wallen...
# Fetching events for Metro Boomin...
# Fetching events for Gente De Zona...
# Fetching events for El Taiger...
# No upcoming events found for El Taiger
# Fetching events for Yomil...
# No upcoming events found for Yomil
# Fetching events for JP Venom...
# No upcoming events found for JP Venom
# Fetching events for Ernesto Losa...
# No upcoming events found for Ernesto Losa
# Fetching events for La Fortaleza Real...
# No upcoming events found for La Fortaleza Real
# Fetching events for Bebeshito...
# Fetching events for Charly & Johayron...
# No upcoming events found for Charly & Johayron
# Fetching events for DJ Conds...
# No upcoming events found for DJ Conds
# Fetching events for Roberto Ferrante...
# No upcoming events found for Roberto Ferrante
# Fetching events for Future...
# Fetching events for Tyler, The Creator...
# No upcoming events found for Tyler, The Creator
# Fetching events for Morgan Wallen...
# Fetching events for Lil Wayne...
# Fetching events for Zach Bryan...
# Fetching events for Luke Combs...
# Fetching events for GloRilla...
# Fetching events for Sexyy Red...
# Fetching events for Lil Baby...
# Fetching events for BigXthaPlug...
# Fetching events for PnB Rock...
# No upcoming events found for PnB Rock
# Fetching events for Lit...
# Fetching events for OT7 Quanny...
# Fetching events for Grateful Dead...
# No upcoming events found for Grateful Dead
# Fetching events for Trans-Siberian Orchestra...
# Fetching events for Jenn Carter...
# No upcoming events found for Jenn Carter
# Fetching events for Taking Back Sunday...
# Fetching events for Dave Matthews Band...
# Fetching events for Jadakiss...
# No upcoming events found for Jadakiss
# Fetching events for Big Time Rush...
# Fetching events for Lil Wayne...
# Fetching events for GloRilla...
# Fetching events for Sexyy Red...
# Fetching events for Kodak Black...
# Fetching events for BigXthaPlug...
# Fetching events for YoungBoy Never Broke Again...
# No upcoming events found for YoungBoy Never Broke Again
# Fetching events for NLE Choppa...
# Fetching events for Moneybagg Yo...
# Fetching events for The Marías...
# No upcoming events found for The Marías
# Fetching events for Cody Johnson...
# Fetching events for Nino Paid...
# No upcoming events found for Nino Paid
# Fetching events for Shy Glizzy...
# No upcoming events found for Shy Glizzy
# Fetching events for No Savage...
# No upcoming events found for No Savage
# Fetching events for SlimeGetEm...
# No upcoming events found for SlimeGetEm
# Fetching events for HavinMotion...
# No upcoming events found for HavinMotion
# Fetching events for KP SKYWALKA...
# No upcoming events found for KP SKYWALKA
# Fetching events for AC640...
# No upcoming events found for AC640
# Fetching events for Fred Hammond...
# Fetching events for Lil Gray...
# No upcoming events found for Lil Gray
# Fetching events for Jaeychino...
# No upcoming events found for Jaeychino
# Fetching events for GloRilla...
# Fetching events for YoungBoy Never Broke Again...
# No upcoming events found for YoungBoy Never Broke Again
# Fetching events for NLE Choppa...
# Fetching events for Moneybagg Yo...
# Fetching events for Tyler Childers...
# Fetching events for Gucci Mane...
# Fetching events for Key Glock...
# No upcoming events found for Key Glock
# Fetching events for Cody Johnson...
# Fetching events for Rod Wave...
# Fetching events for Megan Moroney...
# Fetching events for Ripe...
# No upcoming events found for Ripe
# Fetching events for Dave Portnoy...
# No upcoming events found for Dave Portnoy
# Fetching events for Original Broadway Cast of & Juliet...
# No upcoming events found for Original Broadway Cast of & Juliet
# Fetching events for Nawlage...
# No upcoming events found for Nawlage
# Fetching events for The Standells...
# No upcoming events found for The Standells
# Fetching events for 7981 Kal...
# No upcoming events found for 7981 Kal
# Fetching events for G Fredo...
# No upcoming events found for G Fredo
# Fetching events for Justin David Sullivan...
# No upcoming events found for Justin David Sullivan
# Fetching events for C-Dot 416...
# No upcoming events found for C-Dot 416
# Fetching events for Ben Jackson Walker...
# No upcoming events found for Ben Jackson Walker
# Fetching events for $uicideboy$...
# No upcoming events found for $uicideboy$
# Fetching events for Sublime...
# No upcoming events found for Sublime
# Fetching events for YG...
# No upcoming events found for YG
# Fetching events for Aaron May...
# No upcoming events found for Aaron May
# Fetching events for OHGEESY...
# No upcoming events found for OHGEESY
# Fetching events for Xavier Wulf...
# Fetching events for Shoreline Mafia...
# Fetching events for BONES...
# No upcoming events found for BONES
# Fetching events for Bone Thugs-N-Harmony...
# Fetching events for Baby Bash...
# No upcoming events found for Baby Bash
# Fetching events for Rainbow Kitten Surprise...
# No upcoming events found for Rainbow Kitten Surprise
# Fetching events for Vince Guaraldi Trio...
# No upcoming events found for Vince Guaraldi Trio
# Fetching events for Gregory Alan Isakov...
# Fetching events for Colter Wall...
# Fetching events for AJR...
# No upcoming events found for AJR
# Fetching events for OHGEESY...
# No upcoming events found for OHGEESY
# Fetching events for Shoreline Mafia...
# Fetching events for Caamp...
# No upcoming events found for Caamp
# Fetching events for Mike Sherm...
# Fetching events for Fleet Foxes...
# No upcoming events found for Fleet Foxes
# Fetching events for Mike Sherm...
# Fetching events for Larry June...
# Fetching events for E-40...
# Fetching events for 03 Greedo...
# No upcoming events found for 03 Greedo
# Fetching events for Too $hort...
# No upcoming events found for Too $hort
# Fetching events for Mac Dre...
# No upcoming events found for Mac Dre
# Fetching events for P-Lo...
# No upcoming events found for P-Lo
# Fetching events for SOB X RBE...
# Fetching events for Mozzy...
# No upcoming events found for Mozzy
# Fetching events for Drakeo the Ruler...
# No upcoming events found for Drakeo the Ruler
# Fetching events for BabyTron...
# Fetching events for Rio Da Yung Og...
# No upcoming events found for Rio Da Yung Og
# Fetching events for Skilla Baby...
# Fetching events for Babyfxce E...
# No upcoming events found for Babyfxce E
# Fetching events for Sada Baby...
# No upcoming events found for Sada Baby
# Fetching events for Peezy...
# No upcoming events found for Peezy
# Fetching events for Rmc Mike...
# No upcoming events found for Rmc Mike
# Fetching events for Bfb Da Packman...
# No upcoming events found for Bfb Da Packman
# Fetching events for Icewear Vezzo...
# No upcoming events found for Icewear Vezzo
# Fetching events for Cash Kidd...
# No upcoming events found for Cash Kidd
# Fetching events for Rebelution...
# Fetching events for Brenton Wood...
# No upcoming events found for Brenton Wood
# Fetching events for BlueBucksClan...
# Fetching events for Kalan.FrFr...
# No upcoming events found for Kalan.FrFr
# Fetching events for MoneySign Suede...
# No upcoming events found for MoneySign Suede
# Fetching events for Iration...
# No upcoming events found for Iration
# Fetching events for Bravo the Bagchaser...
# No upcoming events found for Bravo the Bagchaser
# Fetching events for Dom Kennedy...
# Fetching events for Frostydasnowmann...
# No upcoming events found for Frostydasnowmann
# Fetching events for Thee Sinseers...
# Fetching events for Shinedown...
# Fetching events for Theory of a Deadman...
# Fetching events for Little Big Town...
# Fetching events for Montgomery Gentry...
# Fetching events for Sugarland...
# Fetching events for Saving Abel...
# No upcoming events found for Saving Abel
# Fetching events for My Darkest Days...
# No upcoming events found for My Darkest Days
# Fetching events for Trampled by Turtles...
# Fetching events for Pop Evil...
# No upcoming events found for Pop Evil
# Fetching events for Atmosphere...
# Fetching events for Ernesto Losa...
# No upcoming events found for Ernesto Losa
# Fetching events for Bebeshito...
# Fetching events for Charly & Johayron...
# No upcoming events found for Charly & Johayron
# Fetching events for Dany Ome...
# No upcoming events found for Dany Ome
# Fetching events for DJ Unic...
# No upcoming events found for DJ Unic
# Fetching events for Wampi...
# No upcoming events found for Wampi
# Fetching events for Kevincito El 13...
# No upcoming events found for Kevincito El 13
# Fetching events for El Chulo...
# No upcoming events found for El Chulo
# Fetching events for Gatillo...
# No upcoming events found for Gatillo
# Fetching events for Dale Pututi...
# No upcoming events found for Dale Pututi
# Fetching events for Tyler Childers...
# Fetching events for $uicideboy$...
# No upcoming events found for $uicideboy$
# Fetching events for Mt. Joy...
# No upcoming events found for Mt. Joy
# Fetching events for Sublime...
# No upcoming events found for Sublime
# Fetching events for The Red Clay Strays...
# Fetching events for Rainbow Kitten Surprise...
# No upcoming events found for Rainbow Kitten Surprise
# Fetching events for Kenny Chesney...
# No upcoming events found for Kenny Chesney
# Fetching events for Colter Wall...
# Fetching events for Caamp...
# No upcoming events found for Caamp
# Fetching events for Gregory Alan Isakov...
# Fetching events for Doechii...
# Fetching events for Kyle Richh...
# No upcoming events found for Kyle Richh
# Fetching events for 41...
# No upcoming events found for 41
# Fetching events for Cash Cobain...
# No upcoming events found for Cash Cobain
# Fetching events for Sheff G...
# Fetching events for Jenn Carter...
# No upcoming events found for Jenn Carter
# Fetching events for Victoria Monét...
# No upcoming events found for Victoria Monét
# Fetching events for Orion Sun...
# No upcoming events found for Orion Sun
# Fetching events for Fabolous...
# Fetching events for Freddie Gibbs...
# No upcoming events found for Freddie Gibbs
# Fetching events for JONN...
# No upcoming events found for JONN
# Fetching events for DJ Farbreng...
# No upcoming events found for DJ Farbreng
# Fetching events for Vontee the Singer...
# No upcoming events found for Vontee the Singer
# Fetching events for EthoSuave...
# No upcoming events found for EthoSuave
# Fetching events for TAI...
# No upcoming events found for TAI
# Fetching events for Kay Glizz...
# No upcoming events found for Kay Glizz
# Fetching events for Joey Newcomb...
# No upcoming events found for Joey Newcomb
# Fetching events for B Zaro...
# No upcoming events found for B Zaro
# Fetching events for CHII WVTTZ...
# No upcoming events found for CHII WVTTZ
# Fetching events for Wakko The Kidd...
# No upcoming events found for Wakko The Kidd
# Fetching events for Bc tae...
# No upcoming events found for Bc tae
# Fetching events for No Savage...
# No upcoming events found for No Savage
# Fetching events for HavinMotion...
# No upcoming events found for HavinMotion
# Fetching events for Yg Teck...
# No upcoming events found for Yg Teck
# Fetching events for Nasg Chaz...
# No upcoming events found for Nasg Chaz
# Fetching events for mgshorty...
# No upcoming events found for mgshorty
# Fetching events for AC640...
# No upcoming events found for AC640
# Fetching events for KP SKYWALKA...
# No upcoming events found for KP SKYWALKA
# Fetching events for YBS Skola...
# No upcoming events found for YBS Skola
# Fetching events for Mgbabyk...
# No upcoming events found for Mgbabyk
# Fetching events for 03 Greedo...
# No upcoming events found for 03 Greedo
# Fetching events for Drakeo the Ruler...
# No upcoming events found for Drakeo the Ruler
# Fetching events for Brenton Wood...
# No upcoming events found for Brenton Wood
# Fetching events for BlueBucksClan...
# Fetching events for Heembeezy...
# No upcoming events found for Heembeezy
# Fetching events for MoneySign Suede...
# No upcoming events found for MoneySign Suede
# Fetching events for Kalan.FrFr...
# No upcoming events found for Kalan.FrFr
# Fetching events for MemoTheMafioso...
# No upcoming events found for MemoTheMafioso
# Fetching events for Bravo the Bagchaser...
# No upcoming events found for Bravo the Bagchaser
# Fetching events for Frostydasnowmann...
# No upcoming events found for Frostydasnowmann
# Fetching events for Frostydasnowmann...
# No upcoming events found for Frostydasnowmann
# Fetching events for Dom Kennedy...
# Fetching events for Lil Rob...
# No upcoming events found for Lil Rob
# Fetching events for Peysoh...
# No upcoming events found for Peysoh
# Fetching events for Bino Rideaux...
# No upcoming events found for Bino Rideaux
# Fetching events for R3 DA Chilliman...
# No upcoming events found for R3 DA Chilliman
# Fetching events for The Delfonics...
# No upcoming events found for The Delfonics
# Fetching events for OTM...
# No upcoming events found for OTM
# Fetching events for DJ Quik...
# Fetching events for 8K...
# No upcoming events found for 8K
# Fetching events for The Devil Makes Three...
# Fetching events for Allah-Las...
# No upcoming events found for Allah-Las
# Fetching events for Langhorne Slim...
# Fetching events for Mat Kearney...
# Fetching events for Andre Nickatina...
# Fetching events for The Decemberists...
# No upcoming events found for The Decemberists
# Fetching events for Prof...
# Fetching events for Blitzen Trapper...
# No upcoming events found for Blitzen Trapper
# Fetching events for The Secret Sisters...
# Fetching events for M. Ward...
# No upcoming events found for M. Ward
# Fetching events for George Strait...
# No upcoming events found for George Strait
# Fetching events for That Mexican OT...
# No upcoming events found for That Mexican OT
# Fetching events for Midland...
# Fetching events for Parker McCollum...
# Fetching events for Billy Currington...
# Fetching events for Paul Wall...
# No upcoming events found for Paul Wall
# Fetching events for Flatland Cavalry...
# Fetching events for South Park Mexican...
# No upcoming events found for South Park Mexican
# Fetching events for Randy Rogers Band...
# Fetching events for Turnpike Troubadours...
# Fetching events for Mike Sherm...
# Fetching events for Shoreline Mafia...
# Fetching events for EBK Jaaybo...
# No upcoming events found for EBK Jaaybo
# Fetching events for E-40...
# Fetching events for 03 Greedo...
# No upcoming events found for 03 Greedo
# Fetching events for Too $hort...
# No upcoming events found for Too $hort
# Fetching events for Mozzy...
# No upcoming events found for Mozzy
# Fetching events for Larry June...
# Fetching events for Shordie Shordie...
# Fetching events for EBK Young Joc...
# No upcoming events found for EBK Young Joc
# Fetching events for Larry June...
# Fetching events for SOB X RBE...
# Fetching events for Mac Dre...
# No upcoming events found for Mac Dre
# Fetching events for EBK Young Joc...
# No upcoming events found for EBK Young Joc
# Fetching events for lou deezi...
# Fetching events for Knock2...
# Fetching events for Young Slo-Be...
# No upcoming events found for Young Slo-Be
# Fetching events for Lil Pete...
# No upcoming events found for Lil Pete
# Fetching events for DaBoii...
# No upcoming events found for DaBoii
# Fetching events for DB.Boutabag...
# No upcoming events found for DB.Boutabag
# Fetching events for Stick Figure...
# No upcoming events found for Stick Figure
# Fetching events for Dirty Heads...
# No upcoming events found for Dirty Heads
# Fetching events for Slightly Stoopid...
# Fetching events for Hotboii...
# No upcoming events found for Hotboii
# Fetching events for Wizz Havinn...
# No upcoming events found for Wizz Havinn
# Fetching events for El Snappo...
# No upcoming events found for El Snappo
# Fetching events for Pepper...
# Fetching events for Ganja White Night...
# Fetching events for Tape B...
# Fetching events for The Movement...
# No upcoming events found for The Movement
# Fetching events for Lost Tj...
# No upcoming events found for Lost Tj
# Fetching events for Suitor...
# No upcoming events found for Suitor
# Fetching events for The Broken Relics...
# No upcoming events found for The Broken Relics
# Fetching events for Rhett Price...
# No upcoming events found for Rhett Price
# Fetching events for 216zay...
# No upcoming events found for 216zay
# Fetching events for Stuart...
# No upcoming events found for Stuart
# Fetching events for SVORONNIE...
# No upcoming events found for SVORONNIE
# Fetching events for Angie Haze...
# No upcoming events found for Angie Haze
# Fetching events for marrdrac...
# No upcoming events found for marrdrac
# Fetching events for Surf Team...
# No upcoming events found for Surf Team
# Fetching events for Jimmy Wopo...
# No upcoming events found for Jimmy Wopo
# Fetching events for The Clarks...
# Fetching events for Hardo...
# No upcoming events found for Hardo
# Fetching events for Donnie Iris...
# No upcoming events found for Donnie Iris
# Fetching events for Roger Wood...
# No upcoming events found for Roger Wood
# Fetching events for B Dok...
# No upcoming events found for B Dok
# Fetching events for Happy Louie and Julcia's Polka Band / Happy Louie...
# No upcoming events found for Happy Louie and Julcia's Polka Band / Happy Louie
# Fetching events for Duke Bill...
# No upcoming events found for Duke Bill
# Fetching events for BigHomie MDK...
# No upcoming events found for BigHomie MDK
# Fetching events for Fedd the God...
# No upcoming events found for Fedd the God
# Fetching events for The Ohio State University Marching Band...
# No upcoming events found for The Ohio State University Marching Band
# Fetching events for Mg Sleepy...
# No upcoming events found for Mg Sleepy
# Fetching events for Crossroads Music...
# No upcoming events found for Crossroads Music
# Fetching events for Roadrunner TB...
# No upcoming events found for Roadrunner TB
# Fetching events for 10TA Lil A...
# No upcoming events found for 10TA Lil A
# Fetching events for Liltae2...
# No upcoming events found for Liltae2
# Fetching events for Over the Rhine...
# Fetching events for Tse E2 X Tse Vic...
# No upcoming events found for Tse E2 X Tse Vic
# Fetching events for Wussy...
# No upcoming events found for Wussy
# Fetching events for Savannah Locke...
# No upcoming events found for Savannah Locke
# Fetching events for The Kansas State Pride of Wildcatland Marching Band...
# No upcoming events found for The Kansas State Pride of Wildcatland Marching Band
# Fetching events for Pendergast...
# No upcoming events found for Pendergast
# Fetching events for Quite Frankly...
# No upcoming events found for Quite Frankly
# Fetching events for Davis Keats...
# No upcoming events found for Davis Keats
# Fetching events for Elliott Burns...
# No upcoming events found for Elliott Burns
# Fetching events for Stoney-Doom...
# No upcoming events found for Stoney-Doom
# Fetching events for Matt Wade...
# No upcoming events found for Matt Wade
# Fetching events for The Ephinjis...
# No upcoming events found for The Ephinjis
# Fetching events for Ben Hammack...
# No upcoming events found for Ben Hammack
# Fetching events for Maday...
# No upcoming events found for Maday
# Fetching events for George Strait...
# No upcoming events found for George Strait
# Fetching events for That Mexican OT...
# No upcoming events found for That Mexican OT
# Fetching events for Parker McCollum...
# Fetching events for Midland...
# Fetching events for Flatland Cavalry...
# Fetching events for Paul Wall...
# No upcoming events found for Paul Wall
# Fetching events for Randy Rogers Band...
# Fetching events for Turnpike Troubadours...
# Fetching events for South Park Mexican...
# No upcoming events found for South Park Mexican
# Fetching events for Josh Abbott Band...
# Fetching events for Upchurch...
# No upcoming events found for Upchurch
# Fetching events for Struggle Jennings...
# No upcoming events found for Struggle Jennings
# Fetching events for The Lacs...
# Fetching events for Lil Wyte...
# Fetching events for Doobie...
# No upcoming events found for Doobie
# Fetching events for Taylor Ray Holbrook...
# No upcoming events found for Taylor Ray Holbrook
# Fetching events for Jawga Boyz...
# No upcoming events found for Jawga Boyz
# Fetching events for Nu Breed...
# No upcoming events found for Nu Breed
# Fetching events for Jesse Howard...
# No upcoming events found for Jesse Howard
# Fetching events for Bottleneck...
# No upcoming events found for Bottleneck
# Fetching events for Doobie...
# No upcoming events found for Doobie
# Fetching events for The Ohio State University Marching Band...
# No upcoming events found for The Ohio State University Marching Band
# Fetching events for Chicken P...
# No upcoming events found for Chicken P
# Fetching events for KrispyLife Kidd...
# No upcoming events found for KrispyLife Kidd
# Fetching events for Montana of 300...
# Fetching events for Mg Sleepy...
# No upcoming events found for Mg Sleepy
# Fetching events for RealRichIzzo...
# No upcoming events found for RealRichIzzo
# Fetching events for Twiztid...
# No upcoming events found for Twiztid
# Fetching events for Lil Kee...
# No upcoming events found for Lil Kee
# Fetching events for Bobaflex...
# No upcoming events found for Bobaflex
# Fetching events for Waddie Guapo...
# No upcoming events found for Waddie Guapo
# Fetching events for Traptize Ky...
# No upcoming events found for Traptize Ky
# Fetching events for Liberty Worship Collective...
# No upcoming events found for Liberty Worship Collective
# Fetching events for YSN Capo...
# No upcoming events found for YSN Capo
# Fetching events for Lacorey...
# No upcoming events found for Lacorey
# Fetching events for KEEJAMMINGLIKESHXT...
# No upcoming events found for KEEJAMMINGLIKESHXT
# Fetching events for YsnYc...
# No upcoming events found for YsnYc
# Fetching events for Spenzfrmda4...
# No upcoming events found for Spenzfrmda4
# Fetching events for frontstreet2513...
# No upcoming events found for frontstreet2513
# Fetching events for PL Dae...
# No upcoming events found for PL Dae
# Fetching events for Morgan Wallen...
# Fetching events for Luke Combs...
# Fetching events for Chris Stapleton...
# No upcoming events found for Chris Stapleton
# Fetching events for BigXthaPlug...
# Fetching events for Tyler Childers...
# Fetching events for Jelly Roll...
# Fetching events for NLE Choppa...
# Fetching events for Moneybagg Yo...
# Fetching events for Bailey Zimmerman...
# Fetching events for Brooks & Dunn...
# No upcoming events found for Brooks & Dunn
# Fetching events for SweepersENT...
# No upcoming events found for SweepersENT
# Fetching events for Sdot Go...
# No upcoming events found for Sdot Go
# Fetching events for SugarHill Keem...
# No upcoming events found for SugarHill Keem
# Fetching events for Chow Lee...
# No upcoming events found for Chow Lee
# Fetching events for M Row...
# No upcoming events found for M Row
# Fetching events for Dthang...
# No upcoming events found for Dthang
# Fetching events for Sha EK...
# No upcoming events found for Sha EK
# Fetching events for Bizzy Banks...
# No upcoming events found for Bizzy Banks
# Fetching events for Edot Babyy...
# No upcoming events found for Edot Babyy
# Fetching events for Kenzo Balla...
# No upcoming events found for Kenzo Balla
# Fetching events for Chicken P...
# No upcoming events found for Chicken P
# Fetching events for 414bigfrank...
# No upcoming events found for 414bigfrank
# Fetching events for Mariboy Mula Mar...
# No upcoming events found for Mariboy Mula Mar
# Fetching events for MarijuanaXO...
# No upcoming events found for MarijuanaXO
# Fetching events for Munch Lauren...
# No upcoming events found for Munch Lauren
# Fetching events for Lilrb...
# No upcoming events found for Lilrb
# Fetching events for Lilqua 50...
# No upcoming events found for Lilqua 50
# Fetching events for Big Steff...
# No upcoming events found for Big Steff
# Fetching events for SME TAXFREE...
# No upcoming events found for SME TAXFREE
# Fetching events for Lbf Jay...
# No upcoming events found for Lbf Jay
# Fetching events for 7981 Kal...
# No upcoming events found for 7981 Kal
# Fetching events for G Fredo...
# No upcoming events found for G Fredo
# Fetching events for Y Gizzle...
# No upcoming events found for Y Gizzle
# Fetching events for Illy Dee...
# No upcoming events found for Illy Dee
# Fetching events for DJ M3...
# No upcoming events found for DJ M3
# Fetching events for Jswesley...
# No upcoming events found for Jswesley
# Fetching events for Crooked Coast...
# Fetching events for El Metrolo...
# No upcoming events found for El Metrolo
# Fetching events for Lions Lions...
# No upcoming events found for Lions Lions
# Fetching events for Bochek...
# No upcoming events found for Bochek
# Fetching events for Whoppa Wit Da Choppa...
# No upcoming events found for Whoppa Wit Da Choppa
# Fetching events for J4 Krazy...
# No upcoming events found for J4 Krazy
# Fetching events for SCY Jimm...
# No upcoming events found for SCY Jimm
# Fetching events for Goldenboy Countup...
# No upcoming events found for Goldenboy Countup
# Fetching events for Greenlightt...
# No upcoming events found for Greenlightt
# Fetching events for Kshordy...
# No upcoming events found for Kshordy
# Fetching events for WAWG MAX...
# No upcoming events found for WAWG MAX
# Fetching events for Y&R Mookey...
# No upcoming events found for Y&R Mookey
# Fetching events for Rico Cartel...
# No upcoming events found for Rico Cartel
# Fetching events for Kickkone...
# No upcoming events found for Kickkone
# Fetching events for The Tabernacle Choir at Temple Square...
# No upcoming events found for The Tabernacle Choir at Temple Square
# Fetching events for The Piano Guys...
# Fetching events for Orchestra at Temple Square...
# No upcoming events found for Orchestra at Temple Square
# Fetching events for Strive to Be...
# No upcoming events found for Strive to Be
# Fetching events for Chris LeDoux...
# No upcoming events found for Chris LeDoux
# Fetching events for BYU Vocal Point...
# No upcoming events found for BYU Vocal Point
# Fetching events for Mack Wilberg...
# No upcoming events found for Mack Wilberg
# Fetching events for Paul Cardall...
# No upcoming events found for Paul Cardall
# Fetching events for McKenna Hixson...
# No upcoming events found for McKenna Hixson
# Fetching events for Craig Jessop...
# No upcoming events found for Craig Jessop
# Fetching events for The Osborne Brothers...
# No upcoming events found for The Osborne Brothers
# Fetching events for Starlito...
# No upcoming events found for Starlito
# Fetching events for Ralph Stanley...
# No upcoming events found for Ralph Stanley
# Fetching events for The Stanley Brothers...
# No upcoming events found for The Stanley Brothers
# Fetching events for Co Cash...
# No upcoming events found for Co Cash
# Fetching events for DracBaby...
# No upcoming events found for DracBaby
# Fetching events for Dailey & Vincent...
# No upcoming events found for Dailey & Vincent
# Fetching events for The Dillards...
# No upcoming events found for The Dillards
# Fetching events for Indelible Grace Music...
# No upcoming events found for Indelible Grace Music
# Fetching events for Blue Highway...
# No upcoming events found for Blue Highway
# Fetching events for FTO Sett...
# No upcoming events found for FTO Sett
# Fetching events for Dee Mula...
# No upcoming events found for Dee Mula
# Fetching events for Don Trip...
# No upcoming events found for Don Trip
# Fetching events for Big Homiie G...
# No upcoming events found for Big Homiie G
# Fetching events for Kevo Muney...
# No upcoming events found for Kevo Muney
# Fetching events for DracBaby...
# No upcoming events found for DracBaby
# Fetching events for Johnnie Taylor...
# No upcoming events found for Johnnie Taylor
# Fetching events for Marcellus TheSinger...
# No upcoming events found for Marcellus TheSinger
# Fetching events for F.P.J....
# No upcoming events found for F.P.J.
# Fetching events for Starlito...
# No upcoming events found for Starlito
# Fetching events for Waddie Guapo...
# No upcoming events found for Waddie Guapo
# Fetching events for Traptize Ky...
# No upcoming events found for Traptize Ky
# Fetching events for Lacorey...
# No upcoming events found for Lacorey
# Fetching events for Made...
# No upcoming events found for Made
# Fetching events for Liberty Worship Collective...
# No upcoming events found for Liberty Worship Collective
# Fetching events for Arthur Ash Music Group...
# No upcoming events found for Arthur Ash Music Group
# Fetching events for YsnYc...
# No upcoming events found for YsnYc
# Fetching events for KEEJAMMINGLIKESHXT...
# No upcoming events found for KEEJAMMINGLIKESHXT
# Fetching events for Spenzfrmda4...
# No upcoming events found for Spenzfrmda4
# Fetching events for Young Cassanova...
# No upcoming events found for Young Cassanova
# Fetching events for Mouse On Tha Track...
# No upcoming events found for Mouse On Tha Track
# Fetching events for Ydtheillest...
# No upcoming events found for Ydtheillest
# Fetching events for Realbleeda...
# No upcoming events found for Realbleeda
# Fetching events for Neno Calvin...
# No upcoming events found for Neno Calvin
# Fetching events for Keith Frank...
# No upcoming events found for Keith Frank
# Fetching events for Hd4president...
# No upcoming events found for Hd4president
# Fetching events for Hot Boys...
# No upcoming events found for Hot Boys
# Fetching events for BBE AJ...
# No upcoming events found for BBE AJ
# Fetching events for Wnc Whopbezzy...
# No upcoming events found for Wnc Whopbezzy
# Fetching events for Rebirth Brass Band...
# Fetching events for Getrichzay...
# No upcoming events found for Getrichzay
# Fetching events for Harvey Street...
# No upcoming events found for Harvey Street
# Fetching events for Big Yba...
# No upcoming events found for Big Yba
# Fetching events for Damnnnsolo...
# No upcoming events found for Damnnnsolo
# Fetching events for Kdot 600...
# No upcoming events found for Kdot 600
# Fetching events for Summit Worship...
# No upcoming events found for Summit Worship
# Fetching events for Setitoff83...
# No upcoming events found for Setitoff83
# Fetching events for Band of Oz...
# No upcoming events found for Band of Oz
# Fetching events for 556zoo...
# No upcoming events found for 556zoo
# Fetching events for The Chairmen of the Board...
# No upcoming events found for The Chairmen of the Board
# Fetching events for Lil 30...
# No upcoming events found for Lil 30
# Fetching events for Sundy Best...
# Fetching events for Southeast Worship...
# No upcoming events found for Southeast Worship
# Fetching events for 38 Hauncho...
# No upcoming events found for 38 Hauncho
# Fetching events for Bblasian...
# No upcoming events found for Bblasian
# Fetching events for Hblocc Duke...
# No upcoming events found for Hblocc Duke
# Fetching events for TGE Lu Mike...
# No upcoming events found for TGE Lu Mike
# Fetching events for Awaken Worship...
# No upcoming events found for Awaken Worship
# Fetching events for Sons of Habit...
# No upcoming events found for Sons of Habit
# Fetching events for EST SkiMike...
# No upcoming events found for EST SkiMike
# Data updated successfully!
